# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["Harsh" , "Himanshu" , "Sahil" , "Robin"],
    "city":["Kangra" , "Antartica" , "Jammu" , "Solan"],
    "marks":[100 , 0 , 50 , 70]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name       city  marks
# 0     Harsh     Kangra    100
# 1  Himanshu  Antartica      0
# 2     Sahil      Jammu     50
# 3     Robin      Solan     70

# %%
df.to_csv("Random.csv")

# %%
df.to_csv("Random_FalseIndex.csv" , index=False)

# %%
df.drop(2)
# Out:
#        name       city  marks
# 0     Harsh     Kangra    100
# 1  Himanshu  Antartica      0
# 3     Robin      Solan     70

# %%
df.tail(2)
# Out:
#     name   city  marks
# 2  Sahil  Jammu     50
# 3  Robin  Solan     70

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean    55.000000
# std     42.031734
# min      0.000000
# 25%     37.500000
# 50%     60.000000
# 75%     77.500000
# max    100.000000

# %%
harsh = pd.read_csv("Harsh.csv")

# %%
harsh
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Train No  \
# 0           0             0               0                 0     12345
# 1           1             1               1                 1     12343
# 2           2             2               2                 2     12435
# 3           3             3               3                 3     13425
#
#         City  Speed
# 0     Kangra     70
# 1  Antartica    110
# 2      Jammu     50
# 3      Solan     70

# %%
harsh["Speed"]
# Out:
# 0     70
# 1    110
# 2     50
# 3     70
# Name: Speed, dtype: int64

# %%
harsh["Speed"][0]
# Out:
# 70

# %%
harsh["Speed"][0]=70
# Out:
# C:\Users\harsh\AppData\Local\Temp/ipykernel_13224/2515031651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harsh["Speed"][0]=70

# %%
harsh
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Train No  \
# 0           0             0               0                 0     12345
# 1           1             1               1                 1     12343
# 2           2             2               2                 2     12435
# 3           3             3               3                 3     13425
#
#         City  Speed
# 0     Kangra     70
# 1  Antartica    110
# 2      Jammu     50
# 3      Solan     70

# %%
harsh.to_csv("harsh.csv")

# %%
harsh.index = ['first' , 'second' , 'third' , 'fourth']

# %%
harsh
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  Train No  \
# first            0             0               0                 0     12345
# second           1             1               1                 1     12343
# third            2             2               2                 2     12435
# fourth           3             3               3                 3     13425
#
#              City  Speed
# first      Kangra     70
# second  Antartica    110
# third       Jammu     50
# fourth      Solan     70

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.409172
# 1     0.161149
# 2     0.841640
# 3     0.779437
# 4     0.479131
# 5     0.597419
# 6     0.948333
# 7     0.968252
# 8     0.751220
# 9     0.935148
# 10    0.545080
# 11    0.815338
# 12    0.296242
# 13    0.098716
# 14    0.583058
# 15    0.691301
# 16    0.252657
# 17    0.352943
# 18    0.689510
# 19    0.907732
# 20    0.497466
# 21    0.209566
# 22    0.959870
# 23    0.115678
# 24    0.603934
# 25    0.467616
# 26    0.617921
# 27    0.013028
# 28    0.735075
# 29    0.399331
# 30    0.024219
# 31    0.909565
# 32    0.099704
# 33    0.671702
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334 , 5) , index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.893265  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.893265  0.256352  0.404485  0.307107  0.030380
# 1    0.478189  0.810754  0.787230  0.833823  0.149174
# 2    0.668868  0.434698  0.821054  0.105118  0.582538
# 3    0.282972  0.684782  0.494791  0.433686  0.128234
# 4    0.576746  0.393849  0.941056  0.871745  0.776416
# ..        ...       ...       ...       ...       ...
# 329  0.776217  0.667819  0.668619  0.291300  0.096959
# 330  0.795516  0.685804  0.007072  0.186496  0.292254
# 331  0.224501  0.521823  0.515800  0.399225  0.185397
# 332  0.788041  0.375975  0.541100  0.957898  0.812798
# 333  0.410841  0.689361  0.561885  0.306988  0.503368
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.
# %%
newdf2 = newdf.copy()

# %%
newdf2[0][0] = 1
# Out:
# C:\Users\harsh\AppData\Local\Temp/ipykernel_13224/3708030497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0] = 1

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0         1  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0     0.343  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf2.loc[0 , 0] = 2

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0         2  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf2.loc[0 , 1] = 2

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0         2  2.000000  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf2[0][1]
# Out:
# 0.4781886709084533

# %%
newdf2[1][0]
# Out:
# 2.0

# %%
newdf2.columns = list("ABCDE")

# %%
newdf2.head()
# Out:
#           A         B         C         D         E
# 0         2  2.000000  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf[0 , 0] = 223

# %%
newdf.head()
# Out:
#           0         1         2         3         4  (0, 0)
# 0     0.343  0.256352  0.404485  0.307107  0.030380     223
# 1  0.478189  0.810754  0.787230  0.833823  0.149174     223
# 2  0.668868  0.434698  0.821054  0.105118  0.582538     223
# 3  0.282972  0.684782  0.494791  0.433686  0.128234     223
# 4  0.576746  0.393849  0.941056  0.871745  0.776416     223

# %%
newdf.drop((0 , 0), axis=1)
# Out:
#             0         1         2         3         4
# 0       0.343  0.256352  0.404485  0.307107  0.030380
# 1    0.478189  0.810754  0.787230  0.833823  0.149174
# 2    0.668868  0.434698  0.821054  0.105118  0.582538
# 3    0.282972  0.684782  0.494791  0.433686  0.128234
# 4    0.576746  0.393849  0.941056  0.871745  0.776416
# ..        ...       ...       ...       ...       ...
# 329  0.776217  0.667819  0.668619  0.291300  0.096959
# 330  0.795516  0.685804  0.007072  0.186496  0.292254
# 331  0.224501  0.521823  0.515800  0.399225  0.185397
# 332  0.788041  0.375975  0.541100  0.957898  0.812798
# 333  0.410841  0.689361  0.561885  0.306988  0.503368
#
# [334 rows x 5 columns]

# %%
newdf = newdf.drop((0 , 0) , axis=1)

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0     0.343  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416

# %%
newdf2.loc[[1 , 2] , ['C' , 'D']]
# Out:
#           C         D
# 1  0.787230  0.833823
# 2  0.821054  0.105118

# %%
newdf2.loc[: , ['C' , 'D']]
# Out:
#             C         D
# 0    0.404485  0.307107
# 1    0.787230  0.833823
# 2    0.821054  0.105118
# 3    0.494791  0.433686
# 4    0.941056  0.871745
# ..        ...       ...
# 329  0.668619  0.291300
# 330  0.007072  0.186496
# 331  0.515800  0.399225
# 332  0.541100  0.957898
# 333  0.561885  0.306988
#
# [334 rows x 2 columns]

# %%
newdf2.loc[[1 , 2] , :]
# Out:
#           A         B         C         D         E
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538

# %%
newdf.loc[(newdf[0]>.3)]
# Out:
#             0         1         2         3         4
# 0       0.343  0.256352  0.404485  0.307107  0.030380
# 1    0.478189  0.810754  0.787230  0.833823  0.149174
# 2    0.668868  0.434698  0.821054  0.105118  0.582538
# 4    0.576746  0.393849  0.941056  0.871745  0.776416
# 5    0.680828  0.553161  0.735673  0.390765  0.223582
# ..        ...       ...       ...       ...       ...
# 328  0.366163  0.725959  0.731893  0.893494  0.322537
# 329  0.776217  0.667819  0.668619  0.291300  0.096959
# 330  0.795516  0.685804  0.007072  0.186496  0.292254
# 332  0.788041  0.375975  0.541100  0.957898  0.812798
# 333  0.410841  0.689361  0.561885  0.306988  0.503368
#
# [227 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0     0.343  0.256352  0.404485  0.307107  0.030380
# 1  0.478189  0.810754  0.787230  0.833823  0.149174
# 2  0.668868  0.434698  0.821054  0.105118  0.582538
# 3  0.282972  0.684782  0.494791  0.433686  0.128234
# 4  0.576746  0.393849  0.941056  0.871745  0.776416
